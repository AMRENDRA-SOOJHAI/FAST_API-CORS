# %%
class Sample:
    def add(self,a, b):
        print("Addition is done")
        return a + b

# %%
obj = Sample()

# %%
print(obj.add(2, 3))
# Out:
# Addition is done
# 5

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 obj.add(1,2)
#
# TypeError: Sample.add() takes 2 positional arguments but 3 were given
