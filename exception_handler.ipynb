# %%
while True:
    x=''
    try:
        x = int(input("Please enter a number: "))
        print(f"I entered: {x}")
        break
    except ValueError:
        print("Oops!  That was no valid number.  Try again...")
# Out:
# Oops!  That was no valid number.  Try again...
# I entered: 1

# %%
while True:
    x=input("Please enter a number: ")
    print(f"I entered: {x}")
    if type(x)==int:
        break
    else:
        print("Oops!  That was no valid number.  Try again...")
# Out:
# I entered: no
# Oops!  That was no valid number.  Try again...
# I entered: 1
# Oops!  That was no valid number.  Try again...
# I entered: hello
# Oops!  That was no valid number.  Try again...
# I entered: "hi"
# Oops!  That was no valid number.  Try again...

# %%
x=1
try:
    x = int(input("Number enter: "))
    print(f"Result---: {10 / x}")

except ValueError:
    print(" Number hi ni hai ")

except ZeroDivisionError:
    print(" Zero division error")

finally:
    print("always run")
# Out:
# Result---: 5.0
# always run

# %%
class Parent:
    def call(self):
        print("Parent ka show method")


class Child(Parent):
    def call(self):
        super().call()
        print("Child override method of parent class")

# %%
c = Child()
c.call()
# Out:
# Parent ka show method
# Child override method of parent class

# %%
p=Parent()
p.call()
# Out:
# Parent ka show method
